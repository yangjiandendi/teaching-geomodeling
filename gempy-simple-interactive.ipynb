# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
import gempy_simple
import importlib
importlib.reload(gempy_simple)
# Out:
# <module 'gempy_simple' from '/Users/zhouji/Documents/github/teaching-geomodeling/gempy_simple.py'>

# %%
intp = gempy_simple.interp_with_drift()

# %%
layer1 = np.array([[0, 0], [2, 0], [3, 0], [4, 0]])
layer2 = np.array([[0, 2], [2, 2], [3, 3]])

# %%
gempy_simple.plot_interp_with_drift(point_1_y = 2.,
                                    point_2_y = 2.4,
                                    G_1_x=0,
                                    show_contours=False, 
                                    show_field=False,
                                    pick_contour=False,
                                    contour_val=2.8)

# %%
from ipywidgets import interactive                      # widgets and interactivity
from ipywidgets import widgets                            
from ipywidgets import Layout
from ipywidgets import Label
from ipywidgets import VBox, HBox

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
interact(gempy_simple.plot_interp_with_drift,
         point_1_y=(1.,3.,0.1),
         point_2_y=(1.,3.,0.1),
         contour_val=(1.,3.,0.1));
# Out:
# interactive(children=(FloatSlider(value=2.0, description='point_1_y', max=3.0, min=1.0), FloatSlider(value=3.0…

# %%
gempy_simple.plot_interp_with_drift(show_contours = True,show_field=True,pick_contour=True)
plt.savefig('/Users/zhouji/Documents/Presentations/IRTG 2020/Presentation 2020/input/kriging.png')
